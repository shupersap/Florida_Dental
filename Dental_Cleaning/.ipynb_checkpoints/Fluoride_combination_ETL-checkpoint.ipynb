# %%
import pandas as pd

# %%
#read in fluoride df
fluoride_df=pd.read_csv("../Clean_Data/Florida_Fluoride_2023.csv",encoding="ISO-8859-1")

# %%
fluoride_df
# Out:
#           PWS ID                        PWS Name        Status  \
# 0     FL-1030050         BAY COUNTY WATER SYSTEM      Adjusted
# 1     FL-1030141  CALLAWAY, CITY OF WATER SYSTEM   Consecutive
# 2     FL-1030148  SPRINGFIELD, CITY OF WTR. SYS.   Consecutive
# 3     FL-1030435  LYNN HAVEN, CITY OF WATER SYS.   Consecutive
# 4     FL-1030467           MEXICO BEACH, CITY OF  Non-Adjusted
# ...          ...                             ...           ...
# 1600  FL-6604862      LITTLE SUMTER UTILITIES #1  Non-Adjusted
# 1601  FL-6605002              JUMPER CREEK MANOR  Non-Adjusted
# 1602  FL-6605012            NORTH SUMTER UTILITY  Non-Adjusted
# 1603  FL-6605023    ORANGE BLOSSOM UTILITIES INC  Non-Adjusted
# 1604  FL-6605038          CENTRAL SUMTER UTILITY  Non-Adjusted
#
#                 County  Population Served                Fluoride Product  \
# 0        Bay (Primary)              27398                          H2SiF6
# 1        Bay (Primary)              13652                          H2SiF6
# 2        Bay (Primary)               7259                          H2SiF6
# 3        Bay (Primary)              27361                          H2SiF6
# 4        Bay (Primary)               4754  Natural
# ...                ...                ...                             ...
# 1600  Sumter (Primary)              22695  Natural
# 1601  Sumter (Primary)                 45  Natural
# 1602  Sumter (Primary)              39804  Natural
# 1603  Sumter (Primary)                300  Natural
# 1604  Sumter (Primary)              17613  Natural
#
#      Fluoridated Water Source
# 0            Yes      Unknown
# 1            Yes      Surface
# 2            Yes      Surface
# 3            Yes       Ground
# 4             No       Ground
# ...          ...          ...
# 1600          No       Ground
# 1601          No       Ground
# 1602          No       Ground
# 1603          No       Ground
# 1604          No       Ground
#
# [1605 rows x 8 columns]

# %%
#columns to keep
fluoride_subset= fluoride_df[["PWS ID", "Population Served", "Fluoride Product", "Fluoridated", "Water Source"]]

# %%
#keep only the id and drop the Florida associated tag
fluoride_subset["PWS ID"]=fluoride_subset["PWS ID"].str.replace("FL-","")
fluoride_subset.rename(columns={"PWS ID": "PWSID"},inplace=True)
# Out:
# C:\Users\shupe\AppData\Local\Temp\ipykernel_24156\4017172308.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fluoride_subset["PWS ID"]=fluoride_subset["PWS ID"].str.replace("FL-","")
# C:\Users\shupe\AppData\Local\Temp\ipykernel_24156\4017172308.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fluoride_subset.rename(columns={"PWS ID": "PWSID"},inplace=True)

# %%
fluoride_subset
# Out:
#         PWSID  Population Served                Fluoride Product Fluoridated  \
# 0     1030050              27398                          H2SiF6         Yes
# 1     1030141              13652                          H2SiF6         Yes
# 2     1030148               7259                          H2SiF6         Yes
# 3     1030435              27361                          H2SiF6         Yes
# 4     1030467               4754  Natural                                 No
# ...       ...                ...                             ...         ...
# 1600  6604862              22695  Natural                                 No
# 1601  6605002                 45  Natural                                 No
# 1602  6605012              39804  Natural                                 No
# 1603  6605023                300  Natural                                 No
# 1604  6605038              17613  Natural                                 No
#
#      Water Source
# 0         Unknown
# 1         Surface
# 2         Surface
# 3          Ground
# 4          Ground
# ...           ...
# 1600       Ground
# 1601       Ground
# 1602       Ground
# 1603       Ground
# 1604       Ground
#
# [1605 rows x 5 columns]

# %%
#read in plant flow report
flow_df=pd.read_csv("../Clean_Data/Flow_Data_Report_2023_V1.csv",index_col=0)

# %%
#reformat date section
flow_df["REPORTDATE"] = pd.to_datetime(flow_df["REPORTDATE"].astype(str) + '01', format='%Y%m%d')

# %%
#find the most recent report for each pws
recent_flow_rows = flow_df.loc[flow_df.groupby("PWSID")["REPORTDATE"].idxmax()]

# %%
#columns to keep to merge
recent_flow_kept= recent_flow_rows[["PWSID","OFFICE","DESIGNCAPCITY","PLANTSTATUS","MAX_TREATED","AVG_TREATED"]]

# %%
#convert the pwsid to the same dtype
recent_flow_kept['PWSID'] = recent_flow_kept['PWSID'].astype(str)
fluoride_subset['PWSID'] = fluoride_subset['PWSID'].astype(str)
# Out:
# C:\Users\shupe\AppData\Local\Temp\ipykernel_24156\7030833.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent_flow_kept['PWSID'] = recent_flow_kept['PWSID'].astype(str)
# C:\Users\shupe\AppData\Local\Temp\ipykernel_24156\7030833.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fluoride_subset['PWSID'] = fluoride_subset['PWSID'].astype(str)

# %%
#merge on pwsids, but only keep rows with relation to the fluoride df
first_combine=recent_flow_kept.merge(fluoride_subset,left_on="PWSID",right_on="PWSID", how="inner")

# %%
first_combine
# Out:
#         PWSID OFFICE  DESIGNCAPCITY PLANTSTATUS  MAX_TREATED  AVG_TREATED  \
# 0     1030050    NWD     60000000.0      ACTIVE   19850000.0   17300000.0
# 1     1030141    NWD            1.0      ACTIVE          0.0          0.0
# 2     1030148    NWD            1.0      ACTIVE          0.0          0.0
# 3     1030435    NWD      5832000.0      ACTIVE    2772000.0    1605742.0
# 4     1030467    NWD      1010000.0      ACTIVE     308000.0     247225.0
# ...       ...    ...            ...         ...          ...          ...
# 1511  6604862     CD      5760000.0      ACTIVE    3037000.0    2339032.0
# 1512  6605002     CD       110000.0      ACTIVE      21400.0      18284.0
# 1513  6605012     CD      5764000.0      ACTIVE    1043000.0     629968.0
# 1514  6605023     CD      1728000.0      ACTIVE     223800.0     177505.0
# 1515  6605038     CD      4320000.0      ACTIVE    1650000.0    1085806.0
#
#       Population Served                Fluoride Product Fluoridated  \
# 0                 27398                          H2SiF6         Yes
# 1                 13652                          H2SiF6         Yes
# 2                  7259                          H2SiF6         Yes
# 3                 27361                          H2SiF6         Yes
# 4                  4754  Natural                                 No
# ...                 ...                             ...         ...
# 1511              22695  Natural                                 No
# 1512                 45  Natural                                 No
# 1513              39804  Natural                                 No
# 1514                300  Natural                                 No
# 1515              17613  Natural                                 No
#
#      Water Source
# 0         Unknown
# 1         Surface
# 2         Surface
# 3          Ground
# 4          Ground
# ...           ...
# 1511       Ground
# 1512       Ground
# 1513       Ground
# 1514       Ground
# 1515       Ground
#
# [1516 rows x 10 columns]

# %%
#read in microbiology report
microbio_report=pd.read_csv("../Clean_Data/Microbiological_Report_2023_V1.csv",index_col=0)

# %%
#convert sampledate to datetime
microbio_report["SAMPLEDATE"]=pd.to_datetime(microbio_report["SAMPLEDATE"], format='%d-%b-%y')

# %%
#find the most recent sample date per pws
recent_micro_rows=microbio_report.loc[microbio_report.groupby("PWSID")["SAMPLEDATE"].idxmax()]

# %%
#columns to keep
recent_micro_kept=recent_micro_rows[["PWSID","SYSTEMTYPE","SYSTEMSTATUS","SAMPLETYPE","COLIFORMPRESENT","SAMPLESREQUIRED","SAMPLESTAKEN","METHOD","CHLORINERESIDUAL"]]

# %%
#convert pwsid to string dtype
recent_micro_kept['PWSID']=recent_micro_kept['PWSID'].astype(str)
# Out:
# C:\Users\shupe\AppData\Local\Temp\ipykernel_24156\2018977937.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent_micro_kept['PWSID']=recent_micro_kept['PWSID'].astype(str)

# %%
#incorporate micro data into the first iteration
second_combine = first_combine.merge(recent_micro_kept,how="inner")

# %%
second_combine
# Out:
#         PWSID OFFICE  DESIGNCAPCITY PLANTSTATUS  MAX_TREATED  AVG_TREATED  \
# 0     1030050    NWD     60000000.0      ACTIVE   19850000.0   17300000.0
# 1     1030141    NWD            1.0      ACTIVE          0.0          0.0
# 2     1030148    NWD            1.0      ACTIVE          0.0          0.0
# 3     1030435    NWD      5832000.0      ACTIVE    2772000.0    1605742.0
# 4     1030467    NWD      1010000.0      ACTIVE     308000.0     247225.0
# ...       ...    ...            ...         ...          ...          ...
# 1511  6604862     CD      5760000.0      ACTIVE    3037000.0    2339032.0
# 1512  6605002     CD       110000.0      ACTIVE      21400.0      18284.0
# 1513  6605012     CD      5764000.0      ACTIVE    1043000.0     629968.0
# 1514  6605023     CD      1728000.0      ACTIVE     223800.0     177505.0
# 1515  6605038     CD      4320000.0      ACTIVE    1650000.0    1085806.0
#
#       Population Served                Fluoride Product Fluoridated  \
# 0                 27398                          H2SiF6         Yes
# 1                 13652                          H2SiF6         Yes
# 2                  7259                          H2SiF6         Yes
# 3                 27361                          H2SiF6         Yes
# 4                  4754  Natural                                 No
# ...                 ...                             ...         ...
# 1511              22695  Natural                                 No
# 1512                 45  Natural                                 No
# 1513              39804  Natural                                 No
# 1514                300  Natural                                 No
# 1515              17613  Natural                                 No
#
#      Water Source SYSTEMTYPE SYSTEMSTATUS SAMPLETYPE COLIFORMPRESENT  \
# 0         Unknown  COMMUNITY       ACTIVE          D               N
# 1         Surface  COMMUNITY       ACTIVE          D               N
# 2         Surface  COMMUNITY       ACTIVE          D               N
# 3          Ground  COMMUNITY       ACTIVE          D               N
# 4          Ground  COMMUNITY       ACTIVE          D               N
# ...           ...        ...          ...        ...             ...
# 1511       Ground  COMMUNITY       ACTIVE          D               N
# 1512       Ground  COMMUNITY       ACTIVE          D               N
# 1513       Ground  COMMUNITY       ACTIVE          D               N
# 1514       Ground  COMMUNITY       ACTIVE          D               N
# 1515       Ground  COMMUNITY       ACTIVE          D               N
#
#       SAMPLESREQUIRED  SAMPLESTAKEN METHOD  CHLORINERESIDUAL
# 0                  30            10    CLL              0.79
# 1                  15             5    CLL              0.64
# 2                   9             5    CLL              0.63
# 3                  30             1    CLL              1.52
# 4                   7             8    CLL              0.54
# ...               ...           ...    ...               ...
# 1511               30             2     MF              1.57
# 1512                1             1     MF              1.00
# 1513               50             6     MF              1.40
# 1514                1             1     MF              1.49
# 1515               20             5     MF              1.33
#
# [1516 rows x 18 columns]

# %%
#read in chemical report data
chemical_report=pd.read_csv("../Clean_Data/Chemical_Report_2023_V1.csv",index_col=0)

# %%
chemical_report
# Out:
#           PWSID OFFICE              MAILINGNAME SYSTEMTYPE  POPULATION  \
# 0       1030050    NWD  BAY COUNTY WATER SYSTEM  COMMUNITY       30642
# 1       1030050    NWD  BAY COUNTY WATER SYSTEM  COMMUNITY       30642
# 2       1030050    NWD  BAY COUNTY WATER SYSTEM  COMMUNITY       30642
# 3       1030050    NWD  BAY COUNTY WATER SYSTEM  COMMUNITY       30642
# 4       1030050    NWD  BAY COUNTY WATER SYSTEM  COMMUNITY       30642
# ...         ...    ...                      ...        ...         ...
# 159836  6605038     CD            CSU WTP NO. 1  COMMUNITY       19699
# 159837  6605038     CD            CSU WTP NO. 1  COMMUNITY       19699
# 159838  6605038     CD            CSU WTP NO. 1  COMMUNITY       19699
# 159839  6605038     CD            CSU WTP NO. 1  COMMUNITY       19699
# 159840  6605038     CD            CSU WTP NO. 1  COMMUNITY       19699
#
#        SYSTEMSTATUS SUBPARTH  DESIGNCAP  CONSECIND INSPINIT  ... LOCATIONCODE  \
# 0            ACTIVE        Y   60000000          0       LJ  ...           L3
# 1            ACTIVE        Y   60000000          0       LJ  ...           L3
# 2            ACTIVE        Y   60000000          0       LJ  ...           L3
# 3            ACTIVE        Y   60000000          0       LJ  ...           L3
# 4            ACTIVE        Y   60000000          0       LJ  ...           L2
# ...             ...      ...        ...        ...      ...  ...          ...
# 159836       ACTIVE        N    4320000          0      NaN  ...          AAA
# 159837       ACTIVE        N    4320000          0      NaN  ...          AAA
# 159838       ACTIVE        N    4320000          0      NaN  ...          AAA
# 159839       ACTIVE        N    4320000          0      NaN  ...          AAA
# 159840       ACTIVE        N    4320000          0      NaN  ...          AAA
#
#         ENTRYPOINT     LAB METHOD  ANALYSISDATE      MDL       RDL  \
# 0                N  E83079    UNK      8-Oct-23  0.65666  0.777566
# 1                N  E83079    UNK      9-Nov-23  0.65666  0.777566
# 2                N  E83079  552.3      9-Mar-23  0.90000  0.777566
# 3                N  E83079  552.3     14-Apr-23  0.65666  0.777566
# 4                N  E83079    UNK      8-Oct-23  0.65666  0.777566
# ...            ...     ...    ...           ...      ...       ...
# 159836           Y  E53076    UNK      3-Mar-23  0.65666  0.549900
# 159837           Y  E53076    UNK      3-Mar-23  0.65666  0.549900
# 159838           Y  E53076    UNK      3-Mar-23  0.65666  0.549900
# 159839           Y  E53076    UNK      3-Mar-23  0.65666  0.549900
# 159840           Y  E53076    UNK      3-Mar-23  0.65666  0.549900
#
#        CHLORINERESIDUAL                                  REMARKS  \
# 0                   NaN  W17 - 17TH @ COVE, NW SIDE OF INTERSECT
# 1                   NaN  W17 - 17TH @ COVE, NW SIDE OF INTERSECT
# 2                   NaN                                      W17
# 3                   NaN  W17 - 17TH @ COVE, NW SIDE OF INTERSECT
# 4                   NaN                RW21 - 2521 PALO ALTO AVE
# ...                 ...                                      ...
# 159836              NaN                                      POE
# 159837              NaN                                      POE
# 159838              NaN                                      POE
# 159839              NaN                                      POE
# 159840              NaN                                      POE
#
#        CHLORINERESIDUAL_BINARY
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ...                        ...
# 159836                       0
# 159837                       0
# 159838                       0
# 159839                       0
# 159840                       0
#
# [159841 rows x 30 columns]

# %%
#convert anlaysis to datetime format
chemical_report["ANALYSISDATE"]=pd.to_datetime(chemical_report["ANALYSISDATE"].astype(str), format='%d-%b-%y')

# %%
chemical_report['PWSID']=chemical_report['PWSID'].astype(str)

# %%
recent_chemical_rows=chemical_report.loc[chemical_report.groupby("PWSID")["ANALYSISDATE"].idxmax()]

# %%
kept_chemicals=recent_chemical_rows[["PWSID","SUBPARTH","POPULATION","CONTAMGROUP","CHLORINERESIDUAL_BINARY"]]

# %%
third_combine=second_combine.merge(kept_chemicals,how="inner")

# %%
third_combine
# Out:
#         PWSID OFFICE  DESIGNCAPCITY PLANTSTATUS  MAX_TREATED  AVG_TREATED  \
# 0     1030050    NWD     60000000.0      ACTIVE   19850000.0   17300000.0
# 1     1030141    NWD            1.0      ACTIVE          0.0          0.0
# 2     1030148    NWD            1.0      ACTIVE          0.0          0.0
# 3     1030435    NWD      5832000.0      ACTIVE    2772000.0    1605742.0
# 4     1030467    NWD      1010000.0      ACTIVE     308000.0     247225.0
# ...       ...    ...            ...         ...          ...          ...
# 1480  6604862     CD      5760000.0      ACTIVE    3037000.0    2339032.0
# 1481  6605002     CD       110000.0      ACTIVE      21400.0      18284.0
# 1482  6605012     CD      5764000.0      ACTIVE    1043000.0     629968.0
# 1483  6605023     CD      1728000.0      ACTIVE     223800.0     177505.0
# 1484  6605038     CD      4320000.0      ACTIVE    1650000.0    1085806.0
#
#       Population Served                Fluoride Product Fluoridated  \
# 0                 27398                          H2SiF6         Yes
# 1                 13652                          H2SiF6         Yes
# 2                  7259                          H2SiF6         Yes
# 3                 27361                          H2SiF6         Yes
# 4                  4754  Natural                                 No
# ...                 ...                             ...         ...
# 1480              22695  Natural                                 No
# 1481                 45  Natural                                 No
# 1482              39804  Natural                                 No
# 1483                300  Natural                                 No
# 1484              17613  Natural                                 No
#
#      Water Source  ... SAMPLETYPE COLIFORMPRESENT SAMPLESREQUIRED  \
# 0         Unknown  ...          D               N              30
# 1         Surface  ...          D               N              15
# 2         Surface  ...          D               N               9
# 3          Ground  ...          D               N              30
# 4          Ground  ...          D               N               7
# ...           ...  ...        ...             ...             ...
# 1480       Ground  ...          D               N              30
# 1481       Ground  ...          D               N               1
# 1482       Ground  ...          D               N              50
# 1483       Ground  ...          D               N               1
# 1484       Ground  ...          D               N              20
#
#      SAMPLESTAKEN  METHOD  CHLORINERESIDUAL SUBPARTH  POPULATION CONTAMGROUP  \
# 0              10     CLL              0.79        Y       30642         SOC
# 1               5     CLL              0.64        Y       15269         DBP
# 2               5     CLL              0.63        Y        8118         DBP
# 3               1     CLL              1.52        Y       30601         SOC
# 4               8     CLL              0.54        Y        6180         DBP
# ...           ...     ...               ...      ...         ...         ...
# 1480            2      MF              1.57        N       25538         DBP
# 1481            1      MF              1.00        N          50        INOR
# 1482            6      MF              1.40        N       45214         DBP
# 1483            1      MF              1.49        N         335        INOR
# 1484            5      MF              1.33        N       19699         DBP
#
#       CHLORINERESIDUAL_BINARY
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0
# ...                       ...
# 1480                        1
# 1481                        0
# 1482                        1
# 1483                        0
# 1484                        1
#
# [1485 rows x 22 columns]

# %%
#making sure there is no missing data before saving
for x in third_combine.columns:
    print(f"{x} :", third_combine[x].isna().sum())
# Out:
# PWSID : 0
# OFFICE : 0
# DESIGNCAPCITY : 0
# PLANTSTATUS : 0
# MAX_TREATED : 0
# AVG_TREATED : 0
# Population Served : 0
# Fluoride Product : 0
# Fluoridated : 0
# Water Source : 0
# SYSTEMTYPE : 0
# SYSTEMSTATUS : 0
# SAMPLETYPE : 0
# COLIFORMPRESENT : 0
# SAMPLESREQUIRED : 0
# SAMPLESTAKEN : 0
# METHOD : 0
# CHLORINERESIDUAL : 0
# SUBPARTH : 0
# POPULATION : 0
# CONTAMGROUP : 0
# CHLORINERESIDUAL_BINARY : 0

# %%
#save final df to 
third_combine.to_csv("../Clean_Data/Fluoride_modeling_data.csv")
