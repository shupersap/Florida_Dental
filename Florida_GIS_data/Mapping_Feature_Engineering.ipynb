# %%
import pandas as pd

# %%
GIS_df= pd.read_csv("../Clean_Data/gis_subset.csv",index_col=False)

# %%
GIS_df
# Out:
#        PWS_ID  PLANT_LAT_DD  PLANT_LAT_MM  PLANT_LONG_DD  PLANT_LONG_MM
# 0     1030050            30            12             85             36
# 1     1030141            30             9             85             32
# 2     1030148            30            11             85             37
# 3     1030435            30            14             85             38
# 4     1030435            30            13             85             39
# ...       ...           ...           ...            ...            ...
# 5727  4310005            27            42             80             30
# 5728  4134620            25            55             80             47
# 5729  1660596            30            21             86             11
# 5730  1650785            30            12             84             21
# 5731  1460035            30            50             86             31
#
# [5732 rows x 5 columns]

# %%
fluoride_df=pd.read_csv("../Clean_Data/Fluoride_2019-2023.csv",index_col=False)

# %%
fluoride_df
# Out:
#           PWS ID                        PWS Name        Status  \
# 0     FL-1030050         BAY COUNTY WATER SYSTEM      Adjusted
# 1     FL-1030141  CALLAWAY, CITY OF WATER SYSTEM   Consecutive
# 2     FL-1030148  SPRINGFIELD, CITY OF WTR. SYS.   Consecutive
# 3     FL-1030435  LYNN HAVEN, CITY OF WATER SYS.  Non-Adjusted
# 4     FL-1030467           MEXICO BEACH, CITY OF   Consecutive
# ...          ...                             ...           ...
# 8019  FL-6604862      LITTLE SUMTER UTILITIES #1  Non-Adjusted
# 8020  FL-6605002              JUMPER CREEK MANOR  Non-Adjusted
# 8021  FL-6605012            NORTH SUMTER UTILITY  Non-Adjusted
# 8022  FL-6605023    ORANGE BLOSSOM UTILITIES INC  Non-Adjusted
# 8023  FL-6605038          CENTRAL SUMTER UTILITY  Non-Adjusted
#
#                 County  Population Served                Fluoride Product  \
# 0        Bay (Primary)              26466                          H2SiF6
# ...
